# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('IBM-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Randomly select 100 rows from the DataFrame
random_rows = df.sample(n=100, random_state=42)

# %%
random_rows = random_rows.drop(columns=['Attrition'])

# Create a new DataFrame with the selected rows
new_df = pd.DataFrame(random_rows)

# Display the new DataFrame
new_df.head()
# Out:
#       Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 1041   28  Travel_Rarely        866                   Sales                 5
# 184    53  Travel_Rarely       1084  Research & Development                13
# 1222   24  Travel_Rarely        240         Human Resources                22
# 67     45  Travel_Rarely       1339  Research & Development                 7
# 220    36  Travel_Rarely       1396  Research & Development                 5
#
#       Education   EducationField  EmployeeCount  EmployeeNumber  \
# 1041          3          Medical              1            1469
# 184           2          Medical              1             250
# 1222          1  Human Resources              1            1714
# 67            3    Life Sciences              1              86
# 220           2    Life Sciences              1             304
#
#       EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
attrition_counts = new_df['Attrition'].value_counts()

# Display the counts
print(attrition_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attrition'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
diff_count = attrition_counts['No'] - attrition_counts['Yes']

# Sample 'Yes' values to balance the counts
additional_yes_values = df[df['Attrition'] == 'Yes'].sample(n=diff_count, replace=True)

# Append sampled 'Yes' values to the DataFrame
df = pd.concat([df, additional_yes_values], ignore_index=True)

# Count the new distinct values under the 'Attrition' column
new_attrition_counts = df['Attrition'].value_counts()

# Display the new counts
print(new_attrition_counts)
# Out:
# Attrition
# Yes    1233
# No     1233
# Name: count, dtype: int64

# %%
# Save the new DataFrame as "machine_Test_data.csv"
new_df.to_csv('machine_test_data.csv', index=False)
